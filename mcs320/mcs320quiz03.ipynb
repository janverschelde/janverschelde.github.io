# %% [markdown]
# Quiz 3 MCS 320 Friday 11 September 2026

# %% [markdown]
# # Question 1

# %% [markdown]
# Show how to prevent the evaluation of $\sqrt{4 \pi^2}$.
#
# Given the expression of $\sqrt{4 \pi^2}$, show its evaluation.

# %% [markdown]
# ## answer to question 1

# %%
e = sqrt(4*pi^2, hold=True)
show(e)
# Out:
# sqrt(4*pi^2)

# %%
e.unhold()
# Out:
# 2*pi

# %% [markdown]
# # Question 2

# %%
Execute in a SageMath code cell the statement ``thePi = pi``. 

After this command, ``thePi`` refers to ``pi``.

1. What is the command for a new variable ``myPi`` to refer to ``thePi``?

2. Give the commands to verify that ``myPi`` refers to ``thePi`` and evaluates to ``pi``.

# %% [markdown]
# ## answer to question 2

# %%
thePi = pi

# %%
thePi
# Out:
# pi

# %%
myPi = 'thePi'
myPi
# Out:
# 'thePi'

# %%
eval(myPi)
# Out:
# pi

# %%
eval('myPi')
# Out:
# 'thePi'

# %% [markdown]
# Evaluation of the variable ``myPi`` gives ``pi``, while evaluating the name of the variable ``myPi`` gives ``thePi``.
